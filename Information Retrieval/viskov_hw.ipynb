# %%
import numpy as np
import math
import pickle
from collections import defaultdict
import re

import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet

import pyaspeller
from pymystem3 import Mystem
from langdetect import detect

from string import punctuation
from PyDictionary import PyDictionary
from rank_bm25 import BM25Plus
from gensim.summarization.bm25 import get_bm25_weights

import googletrans
#from translate import Translator
from yandex.Translater import Translater

import sys
import time
import os
import platform
from itertools import combinations
import multiprocessing
from io import StringIO
from multiprocessing import freeze_support

from lxml import etree
from html.parser import HTMLParser
# Out:
# [nltk_data] Downloading package wordnet to /home/twinkle/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
N_DOCUMENTS = 38114
MEAN_DOCLEN = 12155
TOTAL_LEMMS = N_DOCUMENTS * MEAN_DOCLEN

K1 = 1
K2 = 1 / 800

W_PAIR = 0.3

W_P = 2
W_I = 0.7
W_S = 0.5
W_W = 0.3

W_ALL = 0.2

# %%
queries_path = './data/queries.numerate.txt'
queries_processed_path = './data/queries.numerate_processed_stem.txt'

change_lang = ('da', 'sq', 'cy')
change_rule = {
    'q': 'й', 'w': 'ц', 'e': 'у', 'r': 'к', 't': 'е', 'y': 'н', 'u': 'г', 'i': 'ш',
    'o': 'щ', 'p': 'з', '[': 'х', ']': 'ъ', 'a': 'ф', 's': 'ы', 'd': 'в', 'f': 'а',
    'g': 'п', 'h': 'р', 'j': 'о', 'k': 'л', 'l': 'д', ';': 'ж', '\'': 'э', 'z': 'я',
    'x': 'ч', 'c': 'с', 'v': 'м', 'b': 'и', 'n': 'т', 'm': 'ь', ',': 'б', '.': 'ю'
    }

digits = set('1234567890')
en_symbols = set('abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ')
ru_symbols = set('йцукенгшщзхъэждлорпавыфячсмитьбюЙЦУКЕНГШЩЗХЪЭЖДЛОРПАВЫФЯЧСМИТЬБЮ')

stemmer = Mystem()
tr = Translater()
tr.set_key('trnsl.1.1.20200117T155615Z.126b37a61e400bbc.afcd42f0d95690d2cbe61991736209c6a6214259')

speller = pyaspeller.YandexSpeller(find_repeat_words=True, ignore_capitalization=True)

# %%
def process_query(query):
    if len(query) == 0:
        return query

    if detect(query) in change_lang:
        query = ''.join(change_rule[c] if c in change_rule.keys() else c for c in query)

    query = ''.join([c if c in en_symbols or c in ru_symbols or c in digits else ' ' for c in query])
    words = [word.lower().strip() for word in query.split(' ')]
    query = ' '.join(words)
    lemmas = stemmer.lemmatize(query)
    query = ' '.join(word for word in lemmas if len(word) > 0 and word != '\n')
    query = re.sub(' +', ' ', query)
    return query

with open(queries_path, 'r', encoding='UTF-8') as queries_file, \
        open(queries_processed_path, 'w', encoding='UTF-8') as queries_processed_file:

    for line in queries_file:
        idx, query = (part.strip() for part in line.split('\t'))
        query = process_query(query)
        correction = speller.spell(query) 

        if len(list(correction)) > 0:
            query_ex = query
            any_corrections = False
            for w in speller.spell(query):
                if len(w['s']) > 0:
                    any_corrections = True
                    query = query.replace(w['word'], w['s'][0])
            query_main = process_query(query)
            if any_corrections == False:
                query_ex = ''
        else:
            query_ex = ''
            query_main = query

        tr.set_text(query_main)
        tr.set_from_lang(tr.detect_lang())
        tr.set_to_lang('en')
        trans = tr.set_text(tr.translate())
        tr.set_from_lang('en')
        tr.set_to_lang('ru')
        query_trans_main = process_query(tr.translate())

        if query_ex:
            tr.set_text(query_ex)
            tr.set_from_lang(tr.detect_lang())
            tr.set_to_lang('en')
            trans = tr.set_text(tr.translate())
            tr.set_from_lang('en')
            tr.set_to_lang('ru')
            query_trans_ex = process_query(tr.translate())
        else:
            query_trans_ex = ''

        print(idx)
        print(query_main)
        print(query_ex)
        print(query_trans_main)
        print(query_trans_ex)
        print('---- ---- ----')

        queries_processed_file.write(idx + '\t' + query_main.strip() + '\t' + \
                                     query_ex.strip() + '\t' + query_trans_main.strip() + '\t' + query_trans_ex.strip() + '\n')
# Out:
# 1
# мультивиз в израиль какой страна можно посещать
#
# мультивиз в израиль как страна можно посещать
#
# ---- ---- ----
# 2
# надо ли носить компресс гольф после операция на голеностоп
# надо ли носить компрес гольф после операция на голеностоп
# нужно ли носить компресс в гольф после операция на лодыжка
# нужно ли я носить оборачивать гольф после операция на лодыжка
# ---- ---- ----
# 3
# жировик на спина можно ли применять пиявка
#
# шишка на спина можно ли применять пиявка
#
# ---- ---- ----
# 4
# как прописывать просто админ
# как прописывать просто адмика
# как зарегистрировать администратор
# как зарегистрировать админ
# ---- ---- ----
# 5
# хто буде судить суперкубок 2017 м ж шахтер динамо кий в дбудеться в одес
#
# хто буде судити суперкубок 2017 м ж шахтар динамо якия в дбудеться в одес
#
# кто быть судить суперкубок 2017 шахтер динамо кий в budelse в одесса
# кто быть судить суперкубок 2017 шахтер динамо акиа в budelse в одесса
# ---- ---- ----
# 6
# как доезжать от метро мякинино до крокус сити молла
#
# как добираться от станция метро до крокус сити молла
#
# ---- ---- ----
# 7
# как заменять подшипник ступица ваз 2121
#
# как заменять подшипник ступица ваз 2121
#
# ---- ---- ----
# 8
# как устанавливать мода сумеречный лес на майн крафт 1 12
# как устанавливать мода сумеречный лес на майнкрафт 1 12
# как устанавливать мода сумеречный лес для minecraft 1 12
# как устанавливать мода сумеречный лес для minecraft 1 12
# ---- ---- ----
# 9
# можно ли ставить горчичник при ларингит
#
# можно ли ставить горчичник при ларингит
#
# ---- ---- ----
# 10
# самый точный прогноз погода в балашов
#
# самый точный прогноз погода в балашов
#
# ---- ---- ----
# 11
# что нейтрализовать ожог борщевик
#
# чтобы нейтрализовать ожог борщевик
#
# ---- ---- ----
# 12
# смородина черный протирать сколько нужно сахар
#
# черный смородина протирать с сахар как вы нужно
#
# ---- ---- ----
# 13
# как подключать роутер
#
# как подключать маршрутизатор
#
# ---- ---- ----
# 14
# от вода зуд в рука почему
#
# от вода зуд в рука почему
#
# ---- ---- ----
# 15
# самый компактный пистолет в ссср
#
# самый компактный пистолет в ссср
#
# ---- ---- ----
# 16
# как подключать двухконтурный газовый котел видео
#
# как подключать двухконтурный котел видео газ
#
# ---- ---- ----
# 17
# если быть один раз вечер можно похудеть
#
# если один ночь можно потерять
#
# ---- ---- ----
# 18
# как вернуть налог в аэропорт париж
# каквернуть налог в аэропорт париж
# как вернуть налог в аэропорт париж
# налог kakorot в парижский аэропорт
# ---- ---- ----
# 19
# как добираться до деревня бобруйск васьково
#
# как добираться до деревня васьковый бобруйск
#
# ---- ---- ----
# 20
# на какой день цикл сдавать т 3
# на какой день цикл сдавать т3
# в какой день цикл принимать т 3
# в какой день цикл сдавать т3
# ---- ---- ----
# 21
# что означать знак бесконечность
#
# что означать знак бесконечность
#
# ---- ---- ----
# 22
# может ли пристав арестовывать алименты
#
# мочь ли судебный пристав арестовывать алименты
#
# ---- ---- ----
# 23
# как быть меняться цена на новостройка в новосибирск в 2018 год
#
# как изменять цена дом в новосибирск в 2018 год
#
# ---- ---- ----
# 24
# что входить в а стоимость авиабилет
# что входитва стоимиость авиабилет
# вход в система и стоимость билет
# что vioditv стоимость билет
# ---- ---- ----
# 25
# где в барнаул купить листогиб
#
# где в барнаул купить листогиб
#
# ---- ---- ----
# 26
# как подымать пост на стена в контакт
#
# как подымать пост на стена в контакт
#
# ---- ---- ----
# 27
# когда можно сажать еще щавель и шпинат
#
# когда можно посадить много щавель и шпинат
#
# ---- ---- ----
# 28
# стоить ли вкладывать в инвестиционный фонд
#
# стоить ли инвестировать в пиф
#
# ---- ---- ----
# 29
# как оформлять отказ от подписание акт о невыход на работа
# какоформлять отказ от подписание акт о невыход на работа
# как подавать заявление на отказ от подписание акт отсутствие на работа
# для icoformat отказ от подписание акт отсутствие на работа
# ---- ---- ----
# 30
# почему с возраст появляться храп
#
# почему возраст появляться храп
#
# ---- ---- ----
# 31
# как проходить миссия трюк на лодка gta vice city
#
# как проходить миссия трюк на лодка в гта вайс сити
#
# ---- ---- ----
# 32
# допустимый ли работа онкобольной в детский учреждение
#
# можно ли работать в онкологический больница
#
# ---- ---- ----
# 33
# как открывать свой чувство любимый
#
# как открывать ваш любимый чувство
#
# ---- ---- ----
# 34
# какой длина должный быть штора
#
# какой длина должный быть слепой
#
# ---- ---- ----
# 35
# как химический путем доказывать наличие примесь сульфат барий в твердый карбонат барий
#
# оба химически доказывать существование примесь сульфат барий в твердый карбонат барий
#
# ---- ---- ----
# 36
# почему много вода пить для почка полезно
#
# зачем много вода пить для почка полезно
#
# ---- ---- ----
# 37
# как вылечивать насморк после аллергия
#
# как вылечивать аллергический ринит после
#
# ---- ---- ----
# 38
# как быстро доставлять письмо
#
# как быстро доставлять письмо
#
# ---- ---- ----
# 39
# сколько лечиться туберкулез по время
#
# как вылечивать туберкулез в тот время
#
# ---- ---- ----
# 40
# как в кс го через консоль сделать маленький прицел
#
# как в кс го консоль чтобы сделать маленький прицел
#
# ---- ---- ----
# 41
# как удалять профиль инстаграм
#
# как удалять профиль instagram
#
# ---- ---- ----
# 42
# сколько платить за кап ремонт в воркута
#
# сколько платить за кап ремонт в воркута
#
# ---- ---- ----
# 43
# какой вопрос задавать парень при знакомство
#
# какой вопрос задавать парень при знакомство
#
# ---- ---- ----
# 44
# может ли работать компьютер без батарейка биос
#
# мочь работать компьютер без батарейка биос
#
# ---- ---- ----
# 45
# что нужный для то что бы проводить свет в гараж
#
# что нужно для то что бы проводить свет в гараж
#
# ---- ---- ----
# 46
# как устанавливать ps cs6
# как устоновлять ps cs6
# как устанавливать ps cs6 теперь
# как устанавливать ps cs6 теперь
# ---- ---- ----
# 47
# чем поливать рассада помидор для быстрый рост
#
# чем поливать рассада помидор для быстрый рост
#
# ---- ---- ----
# 48
# можно ли пить таблетка аугументина с молоко
#
# я мочь пить аугментина таблетка с молоко
#
# ---- ---- ----
# 49
# как создавать новый персонаж в блок страйк
#
# как создавать новый персонаж заблокировать удар
#
# ---- ---- ----
# 50
# как писаться справа
# как пписаться справа
# как писать правильно
# как правильно пиац
# ---- ---- ----
# 51
# кто создавать в речица каплица ефросинья
#
# кто создавать в часовня речица ефросинья
#
# ---- ---- ----
# 52
# нужно ли менять масло в механический коробка передача
#
# нужно ли менять масло в мкпп
#
# ---- ---- ----
# 53
# как подключать передний юсб выход
#
# как подключать выход usb на передний панель
#
# ---- ---- ----
# 54
# как ставить варп в майн крафт
# как ставить варп в майнкрафт
# как поставлять варп в minecraft
# как поставлять варп в minecraft
# ---- ---- ----
# 55
# в какой отель останавливаться в стамбул
#
# какой отель для проживание в стамбул
#
# ---- ---- ----
# 56
# как закаляться становиться
# как закаляться стайл
# как харден становиться
# как харден
# ---- ---- ----
# 57
# как узнавать когда следовать качать м д из улей
#
# как знать когда чтобы следовать чтобы скачать m d из улей
#
# ---- ---- ----
# 58
# что пить от лямблия
# что пить от лямбль
# что пить от лямблия
# что пить от lambl
# ---- ---- ----
# 59
# как сделать ромашка из бумага
#
# как сделать ромашка из бумага
#
# ---- ---- ----
# 60
# как приготавливать вкусный соус к манта
#
# как приготавливать вкусный соус для манта
#
# ---- ---- ----
# 61
# как построить потолок без колонна длина 8 метр
#
# как построить потолок без колонна длина 8 метр
#
# ---- ---- ----
# 62
# на какой поверхность использовать окись цинк для выявление след
#
# на какой поверхность использовать оксид цинк для обнаружение след
#
# ---- ---- ----
# 63
# как устанавливать читалка на планшет самсунг 5 м т561 через пк
#
# как устанавливать читалка на samsung планшет 5 м т561 через пк
#
# ---- ---- ----
# 64
# как снимать порча и сглаз в домашний условие
#
# как снимать порча и сглаз в домашний условие
#
# ---- ---- ----
# 65
# что такой тег
#
# этот тег
#
# ---- ---- ----
# 66
# что кормить крыса
#
# что кормить крыса
#
# ---- ---- ----
# 67
# как удалять квест скайрим
#
# как удалять квест в skyrim
#
# ---- ---- ----
# 68
# от что резкий потеря мощность двигатель авто
#
# от этот внезапный потеря мощность двигатель автомобиль
#
# ---- ---- ----
# 69
# как устанавливать google на veizu
#
# как устанавливать google veizu
#
# ---- ---- ----
# 70
# как сделать загрузочный флешка you tube
#
# как сделать загрузочный флешка вы пробка
#
# ---- ---- ----
# 71
# как быть по английски контактный лицо
#
# как быть по английски контактный лицо
#
# ---- ---- ----
# 72
# где написать завещание в тюмень
#
# где написать завещание в тюмень
#
# ---- ---- ----
# 73
# как избавляться от муравить в на огород народный средство
#
# как избавляться от мораль в сад народный средство
#
# ---- ---- ----
# 74
# что такой асс
# что такой асц
# это жопа
# такой асц
# ---- ---- ----
# 75
# как вставлять рисунок из бронза в железо
#
# как вставлять картинка из бронза к железо
#
# ---- ---- ----
# 76
# какой растение сажать в пруд
#
# какой растение посадить в пруд
#
# ---- ---- ----
# 77
# как понимать что ты нравиться парень
#
# как понимать что ты нравиться парень
#
# ---- ---- ----
# 78
# как закрывать доступ к страница mail ru
#
# как закрывать доступ к почта страница ru
#
# ---- ---- ----
# 79
# кто рождаться сегодня
#
# кто рождаться сегодня
#
# ---- ---- ----
# 80
# как добавлять админ в группа
#
# как добавлять администратор в группа
#
# ---- ---- ----
# 81
# как расширять экран гта 5
#
# как расширять экран гта 5
#
# ---- ---- ----
# 82
# как крепить стропило
#
# как прикреплять стропило
#
# ---- ---- ----
# 83
# почему черный икра терять цвет
#
# почему черный икра потерять цвет
#
# ---- ---- ----
# 84
# хороший средство от колорадский жук
# хороший средство от каларадский жук
# хороший средство от колорадский жук
# хороший средство от колорадский жук
# ---- ---- ----
# 85
# как высчитывать средний дневной заработок
#
# как рассчитать средний дневной заработок
#
# ---- ---- ----
# 86
# допустимый ли добавлять жидкость в акпп
#
# можно ли добавлять жидкость в акпп
#
# ---- ---- ----
# 87
# как написать управляющий опфр по омский область
#
# как писать управляющий опфр по омский область
#
# ---- ---- ----
# 88
# как лечить язык ребенок
#
# как лечить язык ребенок
#
# ---- ---- ----
# 89
# хороший бифокальный линза очки
#
# хороший бифокальный объектив очки
#
# ---- ---- ----
# 90
# как часто можно посещать солярий
#
# как часто можно посещать солярий
#
# ---- ---- ----
# 91
# дибазол через какой время можно повторять курс
#
# дибазол какой время можно повторять курс
#
# ---- ---- ----
# 92
# какой батарейка нужный для радиотелефон филлипс
#
# какой аккумулятор необходимый для радиотелефон филипс
#
# ---- ---- ----
# 93
# как приготавливать раствор для мыльный пузырь дом
#
# как подготовить решение для дом пузырь
#
# ---- ---- ----
# 94
# где купить в казань медилис супер
# где купить в казань медилис ципер
# где купить в казань medelis супер
# где купить в казань medelis молния
# ---- ---- ----
# 95
# что хорошо патрол или инфинити
#
# что хороший патруль или инфинити
#
# ---- ---- ----
# 96
# в какой ифнс платить налог с зарплата дистанционный работник
#
# что ирс платить налог с зарплата дистанционный работник
#
# ---- ---- ----
# 97
# сколько бюджетный место в педагогический колледж
#
# сколько бюджетный место в колледж
#
# ---- ---- ----
# 98
# если женщина бесить это хорошо или плохо
# если женщина бесиш это хорошо или плохо
# если женщина разозлить это хорошо или плохо
# если женщина основа это хорошо или плохо
# ---- ---- ----
# 99
# как поменять пароль на вай фай роутер тплинк
#
# как изменять пароль на wifi роутер tplink
#
# ---- ---- ----
# 100
# что можно сделать свой рука можно торговать на ярмарка
#
# что вы мочь сделать ваш рука мочь быть продавать по справедливый
#
# ---- ---- ----
# 101
# как исчислять соц отчисление
# как исчислять соц отчисление
# как рассчитать социальный отчисление
# как рассчитать социальный отчисление
# ---- ---- ----
# 102
# куда сдавать безвозмездно детский вещь в хабаровск
#
# где взять безвозмездно детский вещь в хабаровск
#
# ---- ---- ----
# 103
# если уровень цена составлять 20 в месяц то такой инфляция называться
# если уровень цена состовлять 20 в месяц то такой инфляция называться
# если уровень цена быть на 20 в месяц то что инфляция называться
# если уровень цена составлять 20 в месяц то инфляция называться
# ---- ---- ----
# 104
# сколько километр от приобье до с кустовой белгородский область яков ленский район
# сколько километр от приобье до с кустовой белгородский область яковлинский район
# сколько километр от сочи до белгородский область буш джейкоб ленский район
# сколько километр от сочи до белгородский область район javlinsky буш
# ---- ---- ----
# 105
# хороший фильм в кинотеатр воронеж
#
# хороший фильм в кинотеатр в воронеж
#
# ---- ---- ----
# 106
# кто отдавать вещь покойный
# кто отдатьвещь покойный
# кто давать вещь поздний
# кто addatives поздно
# ---- ---- ----
# 107
# самый пьяный округ в мир
#
# самый пьяный округ в мир
#
# ---- ---- ----
# 108
# как сохранять видео с вк
#
# как сохранять видео из вк
#
# ---- ---- ----
# 109
# вернуть ли ошибочно зачислять деньги на карта физ лицо
# вернуть ли ошибочно зачислять деньги на карта физ лицо
# возвращение ли это ошибка переводить деньги на карта физический лицо
# возвращение ли это ошибка переводить деньги на карта физический лицо
# ---- ---- ----
# 110
# где можно постирать ковер
#
# где можно помыть ковер
#
# ---- ---- ----
# 111
# что приготавливать в дорога в поезд
#
# что приготавливать в дорога в поезд
#
# ---- ---- ----
# 112
# как посмотреть демо кс 1ю6
#
# как смотреть демо в кс 1ю6
#
# ---- ---- ----
# 113
# витя надо выходить пародия
#
# виктор нужно идти пародия
#
# ---- ---- ----
# 114
# что такой дискорд
#
# например
#
# ---- ---- ----
# 115
# как добавлять значок язык в панель задача
#
# как добавлять значок в панель задача
#
# ---- ---- ----
# 116
# мочь ли солнечный удар повлиять на зрительный нерв
#
# чтобы быть в состояние сделать солнечный удар влиять на зрительный нерв
#
# ---- ---- ----
# 117
# как называться косметический средство что бы уменьшать скула
# как называться косметический средство что бы уменьшетить скула
# как называться косметика для уменьшение скула
# как называть косметический средство который бы umanistici скула
# ---- ---- ----
# 118
# как правильно закапывать капля в глаз
#
# как закапывать капля в глаз
#
# ---- ---- ----
# 119
# вивьен ли
#
# вивьен ли
#
# ---- ---- ----
# 120
# когда выходить 3 сезон супергерл
#
# когда ехать сезон 3 супергерл
#
# ---- ---- ----
# 121
# как прыгать в резиночка
#
# как прыгать в упругий
#
# ---- ---- ----
# 122
# что делать когда мышка не двигаться
#
# что делать когда мышь не двигаться
#
# ---- ---- ----
# 123
# как приготавливать глукамола
#
# дкп gucamole
#
# ---- ---- ----
# 124
# к что сниться расческа для волос
#
# этот сон расчесывать волос
#
# ---- ---- ----
# 125
# можно ли иметь по закон два трудовой книжка
#
# можно ли иметь два закон трудовой книжка
#
# ---- ---- ----
# 126
# как собирать артефакт в герой 3
#
# как собирать артефакт в герой 3
#
# ---- ---- ----
# 127
# куда сходить в самара
#
# куда пойти в самара
#
# ---- ---- ----
# 128
# какой школьный принадлежность нужный в первый класс
#
# какой школьный принадлежность нужный в первый класс
#
# ---- ---- ----
# 129
# как сделать волчик из final
# как сделать олдчик из fnaf
# как сделать волчик от окончательный
# как сделать oldcol из фнаф
# ---- ---- ----
# 130
# как зарегистрироваться в вк без номер
#
# как зарегистрироваться в вк без номер
#
# ---- ---- ----
# 131
# помидор жировать что делать
#
# помидор жировать что делать
#
# ---- ---- ----
# 132
# где устанавливаться второй ключ зажигание ютуб
#
# где устанавливать второй ключ зажигание с youtube
#
# ---- ---- ----
# 133
# как подготавливаться к узи орган брюшной полость
#
# как подготавливаться к узи брюшной полость
#
# ---- ---- ----
# 134
# можно и очищать история в киви
#
# и вы мочь очищать история в киви
#
# ---- ---- ----
# 135
# можно ли без армия устраиваться работать в полиция
#
# возможно ли без армия устраиваться работать в полиция
#
# ---- ---- ----
# 136
# как подкармливать огурец дрожжи
#
# как подкармливать огурец дрожжи
#
# ---- ---- ----
# 137
# как делать скриншот на компьютер
#
# как сделать скриншот на компьютер
#
# ---- ---- ----
# 138
# как ставить значок на клавиатура
#
# как поставлять значок на клавиатура
#
# ---- ---- ----
# 139
# как сбросить чек лад калина универсал 2012 г инжектор
#
# как сбросить чек лад калина универсал инжектор 2012
#
# ---- ---- ----
# 140
# как перекрашивать поезд в трейнз 2012
#
# как перекрашивать поезд в trainz 2012
#
# ---- ---- ----
# 141
# какой польза от календула
#
# как извлекать выгода из календула
#
# ---- ---- ----
# 142
# где отдыхать зима на море за граница недорого
#
# где проводить зима на море за граница недорого
#
# ---- ---- ----
# 143
# как поставлять магический защита
#
# как поставлять магический защита
#
# ---- ---- ----
# 144
# что такой сущий прил и глагол
# что такой сущий прил и глагол
# это существительное прил и глагол
# это существительное прил и глагол
# ---- ---- ----
# 145
# внедрять ли ваш компания новый или существенно улучшать продукция
#
# для реализация являться ли ваш компания новый или значительно улучшать продукт
#
# ---- ---- ----
# 146
# как узнавать задолженность пристав г сыктывкар
# как узнавать задолжность уприставых г сыктывкар
# как находить судебный пристав долг г сыктывкар
# как узнавать долг прествич г сыктывкар
# ---- ---- ----
# 147
# что такой капельный серебро
#
# этот капельный серебро
#
# ---- ---- ----
# 148
# как ия льгота предусматривать закон по участник это принимать совмин кнр читать
# как ия льгота предусматривать закон по участник ато принимать совмин лнр читать
# как иа благо предоставлять право участник принимать совет министр кнр читать
# как иа благо предоставлять право на ато чтобы взять совет министр лнр читать
# ---- ---- ----
# 149
# поменять право в связь с истечение срок годность что нужно 2017
#
# менять право в связь с истечение срок действие для что нужный 2017
#
# ---- ---- ----
# 150
# как копировать контакт с симка в нокиа люмен 520
# как копировать контакт с смки в нокиа люмиа 520
# как скопировать контакт с sim карта в nokia 520 люмен
# как скопировать контакт с smci в nokia lumia 520
# ---- ---- ----
# 151
# где продаваться собака в кызылорд
#
# где продавать собака в кызылорд
#
# ---- ---- ----
# 152
# самый крутой мерседес
#
# самый крутой мерседес
#
# ---- ---- ----
# 153
# почему у хоста желтеть лист
#
# почему желтеть лист хост
#
# ---- ---- ----
# 154
# чем быть заполнять статуя колосс родосский для больший устойчивость
#
# что наполнять статуя колосс родосский для больший устойчивость
#
# ---- ---- ----
# 155
# чем являться экстернат по закон об образование
#
# чем быть экстернат в закон об образование
#
# ---- ---- ----
# 156
# как похудеть народный средство в домашний условие быстро
#
# как похудеть народный средство в домашний условие быстро
#
# ---- ---- ----
# 157
# как приготавливать стерлядь в духовка целиком
#
# как приготавливать стерлядь целиком в духовка
#
# ---- ---- ----
# 158
# где зарегистрировать авторский право
# где зарегестрировать авторский право
# где зарегистрировать авторский право
# где зарегистрировать авторский право
# ---- ---- ----
# 159
# как увеличивать предмет в симс 4
#
# как увеличивать предмет в симс 4
#
# ---- ---- ----
# 160
# что делать если пересолить
#
# что делать если вы пересол
#
# ---- ---- ----
# 161
# как оригинально поздравлять парень
#
# как поздравлять парень
#
# ---- ---- ----
# 162
# какой айфон выпускаться с отпечаток
#
# что на iphone выходить с отпечаток палец
#
# ---- ---- ----
# 163
# как вписывать два страница на 1 лист в майкрософт эксел
#
# как написать два страница на лист 1 в excel
#
# ---- ---- ----
# 164
# хороший роль олеся астахов
# хороший роль олеся фитахова
# хороший роль олеся астахов
# хороший роль олеся петухов
# ---- ---- ----
# 165
# как входить в биос на моноблок asus eeetop
#
# как входить в bios на asus моноблок eeetop
#
# ---- ---- ----
# 166
# как отмывать флажок у газовый плита горение
#
# как мыть окно гореть газовый плита
#
# ---- ---- ----
# 167
# то ли увольнять то ли увольняться
#
# мочь ли увольнять или на пенсия
#
# ---- ---- ----
# 168
# как сделать вобла
#
# как сделать роуч
#
# ---- ---- ----
# 169
# постановлять витя надо выходить
# остоновлять витя надо выходить
# на постановление виктор нужно идти
# виктор надо пойти
# ---- ---- ----
# 170
# как переходить с 8 7 на 9 2
#
# как обновлять с 8 7 до 9 2
#
# ---- ---- ----
# 171
# из что делать соус карий
#
# из что сделать коричневый соус
#
# ---- ---- ----
# 172
# как вы хотеть открывать ссылка такой тип http как убирать
#
# как вы хотеть открывать этот ссылка http как удалять
#
# ---- ---- ----
# 173
# почему закручиваться лист у рассада помидор внутрь
#
# зачем крутить лист у рассада помидор внутри
#
# ---- ---- ----
# 174
# как мама эмили
#
# как мама эмили
#
# ---- ---- ----
# 175
# как женщина кончать
#
# как женщина кончать
#
# ---- ---- ----
# 176
# где можно купить пульт для кондиционер веко в алматы
# где можно купить пульт для кондиционер веко в алмат
# где можно купить пульт для кондиционер веко в алматы
# где можно купить пульт для кондиционер веко в алматы
# ---- ---- ----
# 177
# сколько в пачка шифер штука
#
# сколько в пачка вещь шифер
#
# ---- ---- ----
# 178
# когда сажать гиацинт
#
# когда сажать гиацинт
#
# ---- ---- ----
# 179
# как настраивать в майн русский язык
#
# как настраивать в главное русский язык
#
# ---- ---- ----
# 180
# как переключать передача на гонка
#
# как изменять раса передача
#
# ---- ---- ----
# 181
# как уменьшать холестерин в кровь в домашний условие
#
# как снижать холестерин в кровь в домашний условие
#
# ---- ---- ----
# 182
# как хорошо замариновывать шашлык
# как лутша замариновывать шашлык
# это хороший мариновать шашлык
# как хорошо замариновывать шашлык
# ---- ---- ----
# 183
# как писать пушкинский место
#
# как написать пушкин место
#
# ---- ---- ----
# 184
# как составлять резюме
#
# как составлять резюме
#
# ---- ---- ----
# 185
# если собираться четверо как пойти работа
#
# если вы получать четыре чтобы идти на работа
#
# ---- ---- ----
# 186
# где на клавиатура находиться кнопка backspace
#
# где на клавиатура должный быть кнопка backspace
#
# ---- ---- ----
# 187
# что такой консалтинг
# что такой консалдинг
# такой консультация
# этот консалдинг
# ---- ---- ----
# 188
# какой opengl наradeon 9200 se характеристика
#
# что наradeon характеристика 9200 se с поддержка opengl
#
# ---- ---- ----
# 189
# сколько материк и какой
#
# сколько земля и что
#
# ---- ---- ----
# 190
# как посмотреть фото о нарушение пдд
#
# как просматривать фотография на нарушение правило дорожный движение
#
# ---- ---- ----
# 191
# что такой парафиновый аппликация на шея
#
# этот парафиновый аппликация на шея
#
# ---- ---- ----
# 192
# какой препарат для профилактика кролик
#
# какой препарат для профилактика кролик
#
# ---- ---- ----
# 193
# кто председатель академия наука в казахстан
#
# кто являться председатель академия наука в казахстан
#
# ---- ---- ----
# 194
# как вносить в регион
#
# как вносить в регион
#
# ---- ---- ----
# 195
# можно ли отправляться в дорога в 25 лунный сутки
#
# можно ли идти по дорога в 25 лунный день
#
# ---- ---- ----
# 196
# как нарисовать череп
#
# как нарисовать череп
#
# ---- ---- ----
# 197
# как избавляться от паук в квартира
#
# как избавляться от паук в квартира
#
# ---- ---- ----
# 198
# быть ли какой нибудь проблема при оформление виза в болгария из россия
# быть ли какой нибудь проблема при оформление виза в болгариюю из россия
# должный быть какой то проблема с оформление виза в болгария от россия
# должный быть какой то проблема с оформление виза в болгария от россия
# ---- ---- ----
# 199
# как взламывать игра ice age village
#
# как взламывать игра ледниковый период деревня
#
# ---- ---- ----
# 200
# если оплачивать штраф что ставить в поле 106
#
# если вы заплатить штраф что поставлять в поле 106
#
# ---- ---- ----
# 201
# как челентано
#
# как челентано
#
# ---- ---- ----
# 202
# хороший рисунок для мужской футболка
#
# хороший узор для мужской футболка
#
# ---- ---- ----
# 203
# какой вера в чили
# какой аера в чили
# какой вера в чили
# какой эпоха в чили
# ---- ---- ----
# 204
# кто такой шлюха
#
# кто шлюха
#
# ---- ---- ----
# 205
# куда деваться ведущая анастасия чернобровина
#
# куда пойти ведущая анастасия чернобровина
#
# ---- ---- ----
# 206
# какой сегодня лунный день
#
# какой сегодня лунный день
#
# ---- ---- ----
# 207
# кто такой тата
#
# кто тата
#
# ---- ---- ----
# 208
# чем заменять подоконник на лоджия
#
# как заменять подоконник на лоджия
#
# ---- ---- ----
# 209
# можно ли сдавать обувь по гарантия
#
# можно ли принимать обувь по гарантия
#
# ---- ---- ----
# 210
# кто это персианов соль илецк
# кто это персиянов соль илецк
# кто persianov соль илецк
# кто persianov соль илецк
# ---- ---- ----
# 211
# как записываться 20 й поликлиника
# как записываться 20 й поликленик
# как зарегистрироваться в 20 минута от больница
# как записываться 20 й поликлиника
# ---- ---- ----
# 212
# почему колледж не выставлять рейтинговый список
# почему колледж не выставлять рейтенговый список
# почему в колледж не ставить список оценка
# почему в колледж не ставить список рейтенговый
# ---- ---- ----
# 213
# когда в беларусь прийти тепло
#
# когда в беларусь прийти жара
#
# ---- ---- ----
# 214
# как сделать поводок
#
# как сделать поводок
#
# ---- ---- ----
# 215
# из что делать откос
#
# от что делать уклон
#
# ---- ---- ----
# 216
# у кошка временно прекращаться дыхание что делать
#
# кошка временно переставать дышать что делать
#
# ---- ---- ----
# 217
# как сделать свой сервер в майнкравт 1 8 2017
#
# как сделать свой сервер хороший 1 8 2017
#
# ---- ---- ----
# 218
# как выглядеть укус домашний клоп
#
# как выглядеть укус домашний
#
# ---- ---- ----
# 219
# как приручать дракон 2
#
# как тренировать ваш дракон 2
#
# ---- ---- ----
# 220
# как сделать полка для глоксиния
#
# как сделать полка для ваш глоксиния
#
# ---- ---- ----
# 221
# как укреплять половой член
# как укреаить половой член
# как укреплять пенис
# как ucreate пенис
# ---- ---- ----
# 222
# стоить ли купить эллипсоидный тренажер отзыв
#
# стоимость купить эллиптический тренажер обзор
#
# ---- ---- ----
# 223
# как заменять топливный аппаратура на авт люся
# как заменять топливный аппаратура на авт люсид
# как заменять топливный аппаратура на автобус люся
# как заменять топливный аппаратура по авт ясный
# ---- ---- ----
# 224
# какой бывать вагонка на потолок
#
# что происходить вагонка на потолок
#
# ---- ---- ----
# 225
# как сделать детализация звонок на теле2 чужой номер бесплатно казахстан
#
# как сделать детализация вызов на чужой номер теле2 бесплатно казахстан
#
# ---- ---- ----
# 226
# как открывать весь персонаж в don t starve shipwrecked
#
# как открывать весь персонаж в don т подыхать кораблекрушение
#
# ---- ---- ----
# 227
# как альхам текст
#
# как alham текст
#
# ---- ---- ----
# 228
# что если чесаться правый глаз
#
# если чесаться правый глаз
#
# ---- ---- ----
# 229
# чем замазывать отверстие в евровагонка
#
# чем покрывать отверстие в подкладка
#
# ---- ---- ----
# 230
# как обшивать фундамент профлист
#
# как обшивать фундамент металлический лист
#
# ---- ---- ----
# 231
# как самостоятельно заливать фундамент для дом с мансарда
#
# как заливать фундамент для дом с мансарда
#
# ---- ---- ----
# 232
# чем замазывать шов между плитка в ванная чтобы не стираться
#
# чем прикрывать шов между плитка в ванная так как не исчезать
#
# ---- ---- ----
# 233
# почему в днепр выдавливать масло
# почему в днепр выдовивать масло
# почему в днепр выдавливать масло
# почему в днепр vidoviti масло
# ---- ---- ----
# 234
# как проходить в библиотека реплика
#
# как проходить в библиотека замечание
#
# ---- ---- ----
# 235
# чем снимать засыхать защитный пленка с пластиковый окно
#
# чем снимать сухой защитный пленка с пластиковый окно
#
# ---- ---- ----
# 236
# сколько км от сосновка до гавриловка 1 й новокузнецкий район
#
# сколько км от сосновка до гавриловка 1 й новокузнецкий район
#
# ---- ---- ----
# 237
# как сделать магазин на табличка
# как сделаь магазин на табличка
# как сделать табличка магазин
# как получать магазин на тарелка
# ---- ---- ----
# 238
# хороший автолюлька для новорожденный
#
# хороший система для путешествие для новорожденный
#
# ---- ---- ----
# 239
# как шить обь я буква
# как шить обь мные буква
# как сшивать обь я письмо
# как сшивать буква обь мные
# ---- ---- ----
# 240
# хороший оптовый обувной компания
#
# хороший оптовый обувной компания
#
# ---- ---- ----
# 241
# какой погода быть 7 июль в уфа в прошлый год
#
# какой погода быть 7 июль в уфа в прошлый год
#
# ---- ---- ----
# 242
# как разукрашивать бочка на дача
#
# как украшать бочка на дача
#
# ---- ---- ----
# 243
# какой проводка отражаться передача в казна вклад в уставной капитал
#
# какой проводок отражать передача в казна взнос в уставный капитал
#
# ---- ---- ----
# 244
# на какой счет относить дополнительный расход при приобретение импортный товар
#
# на какой счет относить дополнительный расход на закупка импортный товар
#
# ---- ---- ----
# 245
# когда вс быдло вымирать
#
# когда всякое быдло умирать
#
# ---- ---- ----
# 246
# как лечить горло в домашний условие быстро
#
# как лечить горло дом состояние быстро
#
# ---- ---- ----
# 247
# сколько стоить доллар в 2000 год в россия
#
# сколько стоить доллар в 2000 год в россия
#
# ---- ---- ----
# 248
# причина списание композиция из искусственный цветок
# причина списание композиция из искуственный цветок
# причина для отмена искусственный цветок
# причина для отмена искусственный цветок
# ---- ---- ----
# 249
# кто должный передавать документ в фас в муниципальный образование
#
# кто должный сдавать документ в федеральный антимонопольный служба в муниципалитет
#
# ---- ---- ----
# 250
# что приготавливать с кабачок
#
# что приготавливать с кабачок
#
# ---- ---- ----
# 251
# гинеколог можно сразу определять беременность
#
# немедленно гинеколог определять беременность
#
# ---- ---- ----
# 252
# как устанавливать допы на симс 4
#
# как устанавливать добавление на симс 4
#
# ---- ---- ----
# 253
# как в 1с проводить пошлина
#
# как в 1с чтобы выполнять обязанность
#
# ---- ---- ----
# 254
# с какой возраст можно давать ребенок помидор
#
# с какой возраст можно давать ребенок помидор
#
# ---- ---- ----
# 255
# содержаться ли гормон эстроген в пиво
#
# содержать же гормон эстроген в пиво
#
# ---- ---- ----
# 256
# как с флешка загружать игра икс бокс
#
# как с флешка скачать игра икс бокс
#
# ---- ---- ----
# 257
# почему намораживаться внутренний задний стенка холодильник no frost
#
# почему nemorarius внутренний задний стенка холодильник без иней
#
# ---- ---- ----
# 258
# где поверка счетчик электрический в спб
#
# где тарировка электрический счетчик в санкт петербург
#
# ---- ---- ----
# 259
# как в 1 с бухгалтерия увеличивать зарплата
#
# в 1 с бухгалтерия чтобы увеличивать зарплата
#
# ---- ---- ----
# 260
# как позвонить оператор мтс
#
# как позвонить оператор мтс
#
# ---- ---- ----
# 261
# с что носить пиджак женский
#
# с что носить женский пиджак
#
# ---- ---- ----
# 262
# хороший фильм 2017 год
#
# хороший фильм в 2017 год
#
# ---- ---- ----
# 263
# быть ли максимальный размер пенсионный взнос в казахстан
#
# должный ли быть максимальный размер пенсионный взнос в казахстан
#
# ---- ---- ----
# 264
# какой авто дешево 1 5 млн рубль
#
# какой автомобиль дешево 1 5 млн рубль
#
# ---- ---- ----
# 265
# как перекачивать игра на псп
#
# как закачивать игра на psp
#
# ---- ---- ----
# 266
# сколько км до липецк от донецк
#
# сколько км в липецк из донецк
#
# ---- ---- ----
# 267
# почему акула бояться дельфин
#
# почему акула бояться дельфин
#
# ---- ---- ----
# 268
# как прослушивать радиолюбитель через интернет
#
# как слушать радиолюбитель через интернет
#
# ---- ---- ----
# 269
# когда желтеть и сохнуть нижний лист у помидор
#
# когда пожелтение и засыхание нижний лист у помидор
#
# ---- ---- ----
# 270
# как я звать
#
# я называть
#
# ---- ---- ----
# 271
# как сделать учебный тематический планирование по триместр
#
# как сделать обучение тематический планирование на триместр
#
# ---- ---- ----
# 272
# как узнавать быть ли на телефон nfs
# как узнавать быть ли на телефон nfc
# как узнавать можно ли на телефон нфс
# как узнавать можно ли на телефон nfc
# ---- ---- ----
# 273
# самый крутой сериал в мир
#
# самый крутой сериал в мир
#
# ---- ---- ----
# 274
# как правильно ориентироваться по компас
#
# как ориентироваться по компас
#
# ---- ---- ----
# 275
# как правильно мыть игрушка в доу по санпин
#
# как мыть игрушка в доу по санпин
#
# ---- ---- ----
# 276
# как рассчитывать объем 1 4 цилиндр
# как расчитывать объем 1 4 цилиндр
# как рассчитать объем 1 цилиндр 4
# как рассчитать объем 1 цилиндр 4
# ---- ---- ----
# 277
# сколько день нужно чтобы прописываться в квартира
#
# сколько день должный быть зарегистрировать в квартира
#
# ---- ---- ----
# 278
# кто озвучивать кунг фу панда 2
#
# кто озвучивать кунг фу панда 2
#
# ---- ---- ----
# 279
# как потолстеть в лицо
#
# как поправляться в лицо
#
# ---- ---- ----
# 280
# что такой вердикт
#
# такой постановление
#
# ---- ---- ----
# 281
# что добавлять в фарш вместо хлеб
#
# что добавлять в фарш вместо хлеб
#
# ---- ---- ----
# 282
# как разблокировать телефон если забывать пароль
#
# как разблокировать телефон если забывать пароль
#
# ---- ---- ----
# 283
# как добавлять группа в телеграмма
#
# как добавлять группа в телеграмма
#
# ---- ---- ----
# 284
# когда бойлер нагревать вода из обратный клапан капать вода
#
# когда котел для нагрев вода из обратный клапан капать вода
#
# ---- ---- ----
# 285
# как сделать свой курсор с круглый выбор ссылка
#
# как сделать свой собственный круглый выбор курсор на ссылка
#
# ---- ---- ----
# 286
# почему от некоторый мужчина исходить сильный неприятный запах
#
# почему какой то человек приходить сильный неприятный запах
#
# ---- ---- ----
# 287
# какой нужный в бухучет документ на командировка по перегон автотранспорт
#
# то что требоваться в бухгалтерский документ для поездка по след транспортный средство
#
# ---- ---- ----
# 288
# как перевозить младенец в автомобиль из роддом
#
# как перевозить ребенок в машина из больница
#
# ---- ---- ----
# 289
# куда расходовать спасибо от сбербанк
#
# где потратить спасибо от сбербанк
#
# ---- ---- ----
# 290
# песня ты ли ты ли ты ли я
#
# песня ты ты ты я
#
# ---- ---- ----
# 291
# сколько крутить сила в шуруповерт
#
# сколько сила крутить отвертка
#
# ---- ---- ----
# 292
# как страховать ставка
#
# как страховать ставка
#
# ---- ---- ----
# 293
# что значить 69 поза
#
# значит 69 поза
#
# ---- ---- ----
# 294
# какой выделение мочь быть при удаление маточный труба
#
# что выбор быть с удаление маточный труба
#
# ---- ---- ----
# 295
# сколько ккал организм сжигать за день в 15 год
#
# сколько калория организм сжигать в день в 15 год
#
# ---- ---- ----
# 296
# какой книга прочитывать девочка 15 год
#
# какой книга почитать девушка 15 год
#
# ---- ---- ----
# 297
# быть ли повышаться пенсия по потеря кормилец в 2018 год
#
# быть ли увеличение пенсия по случай потеря кормилец в 2018 год
#
# ---- ---- ----
# 298
# отзыв каша минутка быстрый приготовление со сливочный вкус пром группа кунцево можно готовить ребенок до 3 х год
# отзыв каша минутка быстрый приготовление со сливочный вкус пром группа кунцево можно готовить ребенок до 3 х год
# комментарий наш минута быстрый приготовление со сливочный вкус пром группа кунцево можно подготовить ребенок до 3 год
# комментарий наш минута быстрый приготовление со сливочный вкус пром группа кунцево можно подготовить ребенок до 3 год
# ---- ---- ----
# 299
# как заменять поплавок в унитаз с каков подводка
# как заменять поплавок в унитаз с окова подводка
# как заменять поплавок в унитаз что такой подводка
# как заменять поплавок в унитаз с кандалы подводка
# ---- ---- ----
# 300
# сколько по время идти крещение ребенок
#
# сколько время ехать на крещение ребенок
#
# ---- ---- ----
# 301
# как убирать косточка с нога
#
# как убирать косточка с нога
#
# ---- ---- ----
# 302
# как правильно выбирать лимон
#
# как выбирать правильный лимон
#
# ---- ---- ----
# 303
# сколько человек погибать в война и преступность
#
# сколько человек погибать в война и преступность
#
# ---- ---- ----
# 304
# как находить кнопка термовыключатель в водонагреватель термекс
#
# как находить кнопка тепловой реле в водонагреватель термекс
#
# ---- ---- ----
# 305
# где скачать карта на майн крафт на 1 7 10
# где скачать карта на майнкрафт на 1 7 10
# где скачать карта на майнкрафт 1 7 10
# где скачать карта для майнкрафт 1 7 10
# ---- ---- ----
# 306
# какой время в америка
#
# сколько время в америка
#
# ---- ---- ----
# 307
# какой детский кресло разрешать гибдд
#
# что детский сидение позволять гибдд
#
# ---- ---- ----
# 308
# как заверять трудовой книжка
#
# как заверять трудовой стаж
#
# ---- ---- ----
# 309
# что делать если новорожденный котенок хрипеть и дышать рот
#
# что делать если новорожденный котенок хрипеть и дыхание через рот
#
# ---- ---- ----
# 310
# как пересаживать цветок женский счастие
# как пересаживать цветок женский счастие
# как пересаживать цветок женский счастие
# как пересаживать цветок женский счастие
# ---- ---- ----
# 311
# как устанавливать мода на русский машина в гта сан андреас
#
# как устанавливать мода на русский машина в гта сан андреас
#
# ---- ---- ----
# 312
# как устанавливать дополнение в симс 4
#
# как устанавливать дополнение в симс 4
#
# ---- ---- ----
# 313
# должный ли владелец магазин оплачивать один за электроэнергия если помещение не подключать к прибор учет
# должный ли владелец магазин оплачивать одн за электроэнергия если помещение не подключать к прибор учет
# если владелец магазин платить за электричество если номер не подключать к учетный запись устройство
# если владелец магазин платить за электричество если номер не подключать к учетный запись устройство
# ---- ---- ----
# 314
# полезно ли курение для мужчина
#
# полезно ли для курящий человек
#
# ---- ---- ----
# 315
# что нужно взять в поход
#
# что нужно брать в поход
#
# ---- ---- ----
# 316
# как снижать сахар в моча в домашний условие быстро
#
# как уменьшать сахар в моча быстро в домашний условие
#
# ---- ---- ----
# 317
# как взять перевод деньги на мегафон
#
# как сделать перевод деньги на мегафон
#
# ---- ---- ----
# 318
# какой вкус у иван чай
#
# в иван чай
#
# ---- ---- ----
# 319
# что такой rape me
#
# что такой изнасилование я
#
# ---- ---- ----
# 320
# сколько год хованский
#
# сколько год хованский
#
# ---- ---- ----
# 321
# что ты быть делать во время апокалипсис быть ли ты занятый мочь ли я спасать ты субтитр
#
# что вы быть делать во время апокалипсис чтобы быть если вы занятый я мочь сделать чтобы спасать ты подзаголовок
#
# ---- ---- ----
# 322
# как пользоваться чит энтин на андроид
# как пользуваться чит эндин на андроид
# как использовать чит энтин на андроид
# как пользоватс чит энджин для андроид
# ---- ---- ----
# 323
# кто спеть песня bad boys
#
# кто петь песня плохой парень
#
# ---- ---- ----
# 324
# как узнавать если на ты сглаз или порча
# какузнать если на ты сглаз или порча
# как узнавать если сглаз или порча
# causati если вы сглаз или порча
# ---- ---- ----
# 325
# как прошивать deep ixion ms450
# как прошивать dexp ixion ms450
# как прошивать глубокий иксион ms450
# как прошивать d изм иксион ms450
# ---- ---- ----
# 326
# как прошивать микро флешка 32 гиг кингстон
# как прошивать микрофлешка 32 гиг кингстон
# как прошивать микро usb флеш накопитель 32 гиг кингстоун
# как прошивать микроплазменный 32 гиг кингстоун
# ---- ---- ----
# 327
# если мужчина бывший муж свой девушка что это значить
#
# если человек ваш бывший муж подруга что это значить
#
# ---- ---- ----
# 328
# как скачать карта для кс 1 6
#
# как скачать карта для cs 1 6
#
# ---- ---- ----
# 329
# как самостоятельно организовывать поездка в турция
#
# как организовывать поездка в турция
#
# ---- ---- ----
# 330
# что такой спаечный процесс справа
#
# такой спайка справа
#
# ---- ---- ----
# 331
# куда поехать недалеко от маастрихт
#
# куда пойти рядом с маастрихт
#
# ---- ---- ----
# 332
# как зарегистрироваться на сайт рса
#
# как зарегистрироваться на сайт ога
#
# ---- ---- ----
# 333
# нужный ли учредительный договор
#
# являться ли учредительный договор
#
# ---- ---- ----
# 334
# где лог обновление на windows 2012
#
# где находиться журнал обновление для windows 2012
#
# ---- ---- ----
# 335
# причина нет мочеиспускание
# причина нет мочииспускание
# причина отсутствие мочеиспускание
# причина не mocheispuskanie
# ---- ---- ----
# 336
# когда вышивать даждьбог зимний
#
# при вышивание даждьбог зимний
#
# ---- ---- ----
# 337
# как узнавать код деятельность оквэд
#
# как узнавать код деятельность оквэд
#
# ---- ---- ----
# 338
# что за ошибка 1068 на вино 7
# что за ошибка 1068 на винд 7
# что такой ошибка 1068 на вино 7
# что такой ошибка 1068 на windows 7
# ---- ---- ----
# 339
# можно ли вызывать выкидыш народный средство
#
# можно ли вызывать выкидыш средство
#
# ---- ---- ----
# 340
# как добираться до крым
#
# как добираться в крым
#
# ---- ---- ----
# 341
# больно ли котенок когда кастрировать беременный
#
# больно котенок кастрировать при беременность
#
# ---- ---- ----
# 342
# почему долго не заживать болячка
#
# почему не много время чтобы залечивать рана
#
# ---- ---- ----
# 343
# как переустановить драйвер на звук
#
# как переустановить драйвер на звук
#
# ---- ---- ----
# 344
# как пользоваться креолин для животное от червь
#
# как использовать creolin для животное от червь
#
# ---- ---- ----
# 345
# где купить воблер s c summer 85 f от дайва
# где купить воблер s c salmer 85f от дайва
# где купить воблер ы с 85 ф летний время
# где купить воблер ы с салмер 85ф от дайва
# ---- ---- ----
# 346
# как правильно написать приказ на создание комиссия по приемка объект с ремонт рб
#
# как написать приказ на создание комиссия по приемка объект в ремонт рб
#
# ---- ---- ----
# 347
# надо ли выворачивать штаны при стирка
# надо ли выворвчивать штаны при стирка
# я нужно чтобы превращать штаны в стирка
# излишне vyvorachivayu штаны в стирка
# ---- ---- ----
# 348
# как создавать анкета для регистрация
#
# как создавать анкета для регистрация
#
# ---- ---- ----
# 349
# зачем я ты часть скачать
# зачем я ты асти скачать
# почему я вы часть скачать
# почему я ты асти скачать
# ---- ---- ----
# 350
# как правильно оформлять гарантийный письмо
# как правильно офомить гарантийный письмо
# как оформлять гарантийный письмо
# как ovomit гарантийный письмо
# ---- ---- ----
# 351
# хороший курсы валюта в минск
#
# хороший курсы валюта в минск
#
# ---- ---- ----
# 352
# почему моторный масло попадать в система охлаждение на автомашина опель инсингний
#
# почему моторный масло попадать в система охлаждение на автомобиль опель инсигния
#
# ---- ---- ----
# 353
# что посмотреть в ростов ярославский область
#
# что посмотреть в ростов ярославский область
#
# ---- ---- ----
# 354
# как устанавливать киберлинк директор
#
# как устанавливать директор киберлинк
#
# ---- ---- ----
# 355
# как выдавать себя оружие через консоль
#
# как давать себя оружие через консоль
#
# ---- ---- ----
# 356
# где можно сделать татуаж бровь спб на ветеран
#
# где можно сделать татуаж бровь спб на ветеран
#
# ---- ---- ----
# 357
# что такой летальный оружие
#
# что такой летальный оружие
#
# ---- ---- ----
# 358
# как зайти в skype под другой учетный запись
# как зайти в skipe под другой учетный запись
# как входить в система под другой учетный запись skype
# как skipe входить под другой учетный запись
# ---- ---- ----
# 359
# как сделать дуля с китайский палочка
#
# как сделать дуля из китайский палочка
#
# ---- ---- ----
# 360
# быть ли глиста в сырой куриный мясо
#
# нужно ли быть червь в сырой куриный мясо
#
# ---- ---- ----
# 361
# о чем книга и с тургенев бирюк
#
# о чем книга и бирюк тургенев
#
# ---- ---- ----
# 362
# чем кормить 2 недельный цыпленок
#
# чем кормить 2 неделя цыпочка
#
# ---- ---- ----
# 363
# как правильно поставлять ударение в пословица дарить конь в зуб не смотреть
# как правильно поставлять ударение в пословица дарить конь в зуб не сиотреть
# как поставлять ударение в то чтобы давать конь в зуб не смотреть
# как поставлять ударение в то чтобы давать конь в зуб не цитрат
# ---- ---- ----
# 364
# как скачать видео с ютуб
#
# как скачать видео с youtube
#
# ---- ---- ----
# 365
# как сделать себя стрим
#
# как сделать себя поток
#
# ---- ---- ----
# 366
# как сделать компот из абрикос и слива вместе
#
# как сделать компот из абрикос и алыча вместе
#
# ---- ---- ----
# 367
# как изменять имя персонаж в игра сталкер
#
# как изменять имя персонаж в игра
#
# ---- ---- ----
# 368
# что приготавливать из старый молочка
#
# приготавливать кислый молоко
#
# ---- ---- ----
# 369
# как правильно наносить жидкий стекло wilson
# как правильно наносить жидкий стекло willson
# как применять жидкий стекло вилсон
# как применять жидкий стекло уиллсон
# ---- ---- ----
# 370
# чем отличаться зубной врач от стоматолог
#
# отличаться стоматолог от дантист
#
# ---- ---- ----
# 371
# как оформлять загранпаспорт
#
# как оформлять загранпаспорт
#
# ---- ---- ----
# 372
# как посмотреть сколько оставаться трафик на мтс
#
# как посмотреть сколько оставаться трафик на мтс
#
# ---- ---- ----
# 373
# как перенести убыток прошлый год если налоговый учет не вестись
#
# как перенести убыток прошлый год если налоговый учет не быть
#
# ---- ---- ----
# 374
# сколько калория в дыня колхозница
#
# сколько калория в дыня фермер
#
# ---- ---- ----
# 375
# хороший фильм с джеки чан смотреть онлайн
#
# хороший фильм с джеки чан смотреть онлайн
#
# ---- ---- ----
# 376
# что приготавливать с копа они крыло
# что приготавливать с копча нымь крыло
# что приготавливать с кс они крыло
# что приготавливать с copca имя крыло
# ---- ---- ----
# 377
# чем лечить шпора на пятка в домашний условие
#
# как лечить пяточный шпора в домашний условие
#
# ---- ---- ----
# 378
# как файл пдф переводить в бмп
#
# как файл pdf переводить в bmp
#
# ---- ---- ----
# 379
# как защищать компьютер от реклама и всплывать окно бесплатно
#
# как защищать компьютер от реклама и всплывать бесплатно
#
# ---- ---- ----
# 380
# в какой лекарство быть бета адреноблокатор
#
# какой лекарство бета блокатор
#
# ---- ---- ----
# 381
# от что женщина сквиртовать
#
# от что женщина squirtbag
#
# ---- ---- ----
# 382
# как подкармливать помидор дрожжи
#
# как подкармливать помидор дрожжи
#
# ---- ---- ----
# 383
# что такой ин драйвер
# что такой индрайвер
# это в драйвер
# этот indriver работать
# ---- ---- ----
# 384
# самый большой мр текст
# самый большой ммр текст
# крупный мистер текст
# самый большой текст ммр
# ---- ---- ----
# 385
# почему зеленеть вода в аквариум
#
# почему зеленый вода в аквариум
#
# ---- ---- ----
# 386
# что посмотреть в санкт петербург
#
# что посмотреть в санкт петербург
#
# ---- ---- ----
# 387
# можно ли устанавливать ава в квартира
# можно ли устанавливать агва в квартира
# я мочь устанавливать ава в квартира
# можно ли устанавливать агва в квартира
# ---- ---- ----
# 388
# как защищаться от энергетический вампир начальник
#
# как защищать себя от энергетический вампир начальник
#
# ---- ---- ----
# 389
# как узнавать какой двигатель на мерседес
#
# откуда я знать что двигатель на мерседес
#
# ---- ---- ----
# 390
# какой химикат добавлять в горячий вода
#
# какой вещество добавлять в горячий вода
#
# ---- ---- ----
# 391
# что показывать анализ кровь
#
# что показывать кровь
#
# ---- ---- ----
# 392
# можно ли поставлять место три рядный два рядный радиатор
#
# я мочь поставлять три подряд два радиатор подряд
#
# ---- ---- ----
# 393
# как начисляться больничный при выход из декретный отпуск
# как начисляться больничный при выход из дектетный отпуск
# как начислять больничный лист на выход из декретный отпуск
# как начислять больничный лист на выход decety отпуск
# ---- ---- ----
# 394
# где взять бонус код на сантандер
# где взять бонус код на вантандер
# где взять бонус код для сантандер
# где взять бонус код для сантандер
# ---- ---- ----
# 395
# как узнавать знаменитость по урл картинка
#
# как находить знаменитость в url картинка
#
# ---- ---- ----
# 396
# сколько ккал надо съедать в день
#
# сколько калория нужно быть в день
#
# ---- ---- ----
# 397
# полезный ли творог
#
# полезный сыр
#
# ---- ---- ----
# 398
# как посмотреть статистика посещение в инстаграм
#
# как посмотреть статистика посещение instagram
#
# ---- ---- ----
# 399
# сколько уровень в попа
# сколько уровень в поу
# сколько уровень в поп
# сколько уровень в pou
# ---- ---- ----

# %%
def get_text_stem_files(base_path):
    files = []
    text_dir_paths = [f for f in os.listdir(base_path) if f.count('_') == 3 and f.find('text_stem') >= 0]
    for dir_path in text_dir_paths:
        for file_path in os.listdir(base_path + dir_path):
            yield base_path + dir_path + '/' + file_path


def get_title_stem_files(base_path):
    files = []
    text_dir_paths = [f for f in os.listdir(base_path) if f.count('_') == 3 and f.find('title_stem') >= 0]
    for dir_path in text_dir_paths:
        for file_path in os.listdir(base_path + dir_path):
            yield base_path + dir_path + '/' + file_path


def get_base_file_path(path):
    if path.find('text'):
        path = path.replace('_text', '')
    if path.find('title'):
        path = path.replace('_title', '')
    if path.find('stem'):
        path = path.replace('_stem', '')
    return path


def file_path_to_tf_path(path):
    return path.replace('content', 'statistics/tf').replace('.dat', '.pkz')


def file_path_to_pairs_path(path):
    return path.replace('content', 'statistics/pairs').replace('.dat', '.pkz')


def file_path_to_hop_pairs_path(path):
    return path.replace('content', 'statistics/hop_pairs').replace('.dat', '.pkz')

def file_path_to_hop_hop_pairs_path(path):
    return path.replace('content', 'statistics/hop_hop_pairs').replace('.dat', '.pkz')

# %%
base_path = './data/content/'
url_path = './data/urls.numerate.txt'
num_path = './data/path.numerate.txt'
num_sort_path = './data/path.numerate.sort.txt'
p_n_path = './data/path.numerate.pkz'
n_p_path = './data/numerate.path.pkz'

path_numerate = dict()
numerate_path = dict()
url_to_num = dict()

dir_paths = [f for f in os.listdir(base_path) if f.count('_') == 1]

with open(url_path, 'r', encoding='UTF-8', errors='ignore') as url_file:
    for line in url_file:
        num, url = line.strip().split('\t')
        url_to_num[url] = num

cnt = 0
with open(num_path, 'a', encoding='UTF-8', errors='ignore') as num_file:
    for dir_path in dir_paths:
        file_paths = [f for f in os.listdir(base_path + dir_path)]
        for file_path in file_paths:
            full_file_path = base_path + dir_path + '/' + file_path
            with open(full_file_path, 'r', encoding='UTF-8', errors='ignore') as file:
                url = file.readline().strip()
                num_file.write(full_file_path + '\t' + str(url_to_num[url]) + '\n')
                print('\r{}'.format(cnt), end='')
                cnt += 1

cnt = 0
with open(num_path, 'r', encoding='UTF-8', errors='ignore') as num_file, \
    open(num_sort_path, 'w', encoding='UTF-8', errors='ignore') as num_sort_file:
    paths = defaultdict(str)
    for line in num_file:
        path, idx = (part.strip() for part in line.split('\t'))
        paths[idx] = path
        print('\r{}'.format(cnt), end='')
        cnt += 1
    for i in range(1, int(N_DOCUMENTS) + 1):
        num_sort_file.write(paths[str(i)] + '\t' + str(i) + '\n')

print()        

cnt = 0
with open(num_path, 'r', encoding='UTF-8', errors='ignore') as num_file, \
        open(p_n_path, 'wb') as p_n_file, open(n_p_path, 'wb') as n_p_file:
    for line in num_file:
        path, num = line.strip().split('\t')
        path_numerate[path] = int(num)
        numerate_path[int(num)] = path
        print('\r{}'.format(cnt), end='')
        cnt += 1
    pickle.dump(path_numerate, p_n_file)
    pickle.dump(numerate_path, n_p_file)
# Out:
# 38113
# 38113

# %%
queries_path = './data/queries.numerate_processed_stem.txt'
base_path = './data/queries.numerate_processed_chunks/'
n_splits = 4
split_size = 100

split_files = [open(base_path + 'chunk_{}'.format(str(idx)) + '.txt',
                    'w',
                    encoding='UTF-8',
                    errors='ignore')
               for idx in range(1, n_splits + 1)]

with open(queries_path, 'r', encoding='UTF-8', errors='ignore') as queries_file:
    for line in queries_file:
        idx, query_main, query_ex, query_trans_main, query_trans_ex = (part.strip() for part in line.split('\t'))
        split_files[int(idx) // split_size].write(idx + '\t' + query_main.strip() + '\t' + query_ex.strip() + '\t' + query_trans_main.strip() + '\t' + query_trans_ex.strip() + '\n')

# %%
class TextHTMLParser(HTMLParser):
    def __init__(self):
        HTMLParser.__init__(self)
        self._text = []
        self._title = []
        self._in_title = False

    def handle_data(self, text):
        text = text.strip()
        if len(text) > 0:
            if self.accept_field(text) or self._in_title:
                pass
            else:
                return
            if self._in_title:
                self._title.append(text)
            else:
                self._text.append(text)

    def handle_starttag(self, tag, attrs):
        if tag == 'title':
            self._in_title = True

    def handle_endtag(self, tag):
        if tag == 'title':
            self._in_title = False

    def text(self):
        text = ' '.join(self._text)
        # only literals or digits
        text = re.sub('\W+', ' ', text)
        # split number from text, make lower
        text = ' '.join(re.split('(\d+)', text)).lower()
        text = ' '.join(text.split(' '))
        return text

    def title(self):
        text = ' '.join(self._title)
        # only literals or digits
        text = re.sub('\W+', ' ', text)
        # split number from text, make lower
        text = ' '.join(re.split('(\d+)', text)).lower()
        text = ' '.join(text.split(' '))
        return text

    def accept_field(self, field):
        en_cnt = 0
        ru_cnt = 0
        di_cnt = 0
        for c in field:
            if c in en_symbols:
                en_cnt += 1
            elif c in ru_symbols:
                ru_cnt += 1
            elif c in digits:
                di_cnt += 1
        if en_cnt + ru_cnt == 0:
            return False
        en_proba = en_cnt / (en_cnt + ru_cnt)
        if en_proba < 0.95 or en_cnt == len(field) - ru_cnt - field.count(' '):
            return True
        return False

# %%
def get_text_and_title(path, *args):
    with open(path, 'r', encoding='UTF-8', errors='ignore') as file:
        text = file.read()

        # fix DOM tree using lxml tools
        parser = etree.HTMLParser()
        tree = etree.parse(StringIO(text), parser)
        text = str(etree.tostring(tree.getroot(), pretty_print=True, method="html"), encoding='UTF-8')

        # parse fixed html and get title, text, meta, headers, ...
        parser = TextHTMLParser()
        parser.feed(text)
        return parser.text(), parser.title()

def get_text_and_title_stem(text_path, title_path):
    with open(text_path, 'r', encoding='UTF-8', errors='ignore') as text_file, \
            open(title_path, 'r', encoding='UTF-8', errors='ignore') as title_file:
        text = text_file.read()
        title = title_file.read()

    text_words, title_words = stemmer.lemmatize(text), stemmer.lemmatize(title)

    text = ' '.join(word for word in text_words if len(word) > 0 and word != '\n')
    title = ' '.join(word for word in title_words if len(word) > 0 and word != '\n')
    text = ' '.join(text.split(' '))
    title = ' '.join(title.split(' '))
    return text, title


def prepare_dir(base_path, step_suffix, dir_path, preparer):
    cnt = 0
    # creating directories
    try:
        os.mkdir(base_path + dir_path + step_suffix[0])
    except FileExistsError:
        pass
    try:
        os.mkdir(base_path + dir_path.replace('text', 'title') + step_suffix[1])
    except FileExistsError:
        pass

    file_paths = [f for f in os.listdir(base_path + dir_path)]
    for file_path in file_paths:
        real_path = base_path + dir_path + '/' + file_path
        text_real_path_result = base_path + dir_path + step_suffix[0] + '/' + file_path
        title_real_path_result = base_path + dir_path.replace('text', 'title') + step_suffix[1] + '/' + file_path

        if os.path.exists(text_real_path_result) and os.path.exists(title_real_path_result):
            continue

        text, title = preparer(real_path, real_path.replace('text', 'title'))

        with open(text_real_path_result, 'w', encoding='UTF-8', errors='ignore') as result_file:
            result_file.write(text)
        with open(title_real_path_result, 'w', encoding='UTF-8', errors='ignore') as result_file:
            result_file.write(title)
        print('\r{}'.format(cnt), end='')
        cnt += 1

# %%
base_path = './data/content/'
dir_paths = [f for f in os.listdir(base_path) if f.count('_') == 1]
step_suffix = ['_text', '_title']

for dir_path in dir_paths:
    # get text and title for each document
    prepare_dir(base_path, step_suffix, dir_path, get_text_and_title)
# Out:
# 38113

# %%
base_path = './data/content/'
dir_paths = [f for f in os.listdir(base_path) if f.count('_') == 2 and f.find('text') >= 0]
step_suffix = ['_stem', '_stem']

for dir_path in dir_paths:
    # get stemmed text and title fot each document
    prepare_dir(base_path, step_suffix, dir_path, get_text_and_title_stem)
# Out:
# 38113

# %%
def count_tf(file_generator):
    cnt = 0
    for file_path in file_generator:
        print('\r{}'.format(cnt), end='')
        cnt += 1
        tf_dict = defaultdict(int)
        with open(file_path, 'r', encoding='UTF-8', errors='ignore') as file:
            text = file.read().strip()
            words = text.split(' ')
            for word in words:
                tf_dict[word] += 1

        tf_path = file_path_to_tf_path(file_path)
        os.makedirs(os.path.dirname(tf_path), exist_ok=True)
        with open(tf_path, 'wb') as tf_file:
            pickle.dump(tf_dict, tf_file)

base_path = './data/content/'
base_result_path = './data/statistics/'

count_tf(get_text_stem_files(base_path))
count_tf(get_title_stem_files(base_path))
# Out:
# 38113

# %%
def count_df(file_generator, df_path):
    df_dict = defaultdict(int)
    cnt = 0
    for file_path in file_generator:
        print('\r{}'.format(cnt), end='')
        cnt += 1
        tmp_dict = defaultdict(int)
        with open(file_path, 'r', encoding='UTF-8', errors='ignore') as file:
            text = file.read().strip()
            words = text.split(' ')
            for word in words:
                tmp_dict[word] = 1
        for key in tmp_dict.keys():
            df_dict[key] += 1
    with open(df_path, 'wb') as df_file:
        pickle.dump(df_dict, df_file)


base_path = './data/content/'
base_result_path = './data/statistics/'

text_df_path = base_result_path + 'text_df_count.pkz'
title_df_path = base_result_path + 'title_df_count.pkz'

count_df(get_text_stem_files(base_path), text_df_path)
count_df(get_title_stem_files(base_path), title_df_path)
# Out:
# 38113

# %%
def count_cf(file_generator, cf_path):
    cf_dict = defaultdict(int)
    cnt = 0
    for file_path in file_generator:
        print('\r{}'.format(cnt), end='')
        cnt += 1
        with open(file_path, 'r', encoding='UTF-8', errors='ignore') as file:
            text = file.read().strip()
            words = text.split(' ')
            for word in words:
                cf_dict[word] += 1
    with open(cf_path, 'wb') as cf_file:
        pickle.dump(cf_dict, cf_file)        
        
base_path = './data/content/'
base_result_path = './data/statistics/'

text_cf_path = base_result_path + 'text_cf_count.pkz'
title_cf_path = base_result_path + 'title_cf_count.pkz'

count_cf(get_text_stem_files(base_path), text_cf_path)
count_cf(get_title_stem_files(base_path), title_cf_path)
# Out:
# 38113

# %%
base_path = './data/content/'
p_n_path = './data/path.numerate.pkz'
text_doclen_path = './data/statistics/text_doclen.pkz'
title_doclen_path = './data/statistics/title_doclen.pkz'

with open(p_n_path, 'rb') as p_n_file:
    path_to_num = pickle.load(p_n_file)
    num_to_text_len = defaultdict(int)
    num_to_title_len = defaultdict(int)

    cnt = 0
    for path in get_text_stem_files(base_path):
        print('\r{}'.format(cnt), end='')
        cnt += 1
        base = get_base_file_path(path)
        with open(path, 'r', encoding='UTF-8', errors='ignore') as file:
            num_to_text_len[int(path_to_num[base])] = len(file.read().strip().split(' '))

    with open(text_doclen_path, 'wb') as text_doclen_file:
        pickle.dump(num_to_text_len, text_doclen_file)

    print()

    cnt = 0
    for path in get_title_stem_files(base_path):
        print('\r{}'.format(cnt), end='')
        cnt += 1
        base = get_base_file_path(path)
        with open(path, 'r', encoding='UTF-8', errors='ignore') as file:
            num_to_title_len[int(path_to_num[base])] = len(file.read().strip().split(' '))

    with open(title_doclen_path, 'wb') as title_doclen_file:
        pickle.dump(num_to_title_len, title_doclen_file)
# Out:
# 38113
# 38113

# %%
def count_pairs(file_generator):
    cnt = 0
    for file_path in file_generator:
        print('\r{}'.format(cnt), end='')
        cnt += 1
        pairs_dict = defaultdict(int)
        with open(file_path, 'r', encoding='UTF-8', errors='ignore') as file:
            text = file.read().strip()
            words = text.split(' ')
            for idx in range(len(words) - 1):
                pairs_dict[(words[idx], words[idx + 1])] += 1

        pairs_path = file_path_to_pairs_path(file_path)
        os.makedirs(os.path.dirname(pairs_path), exist_ok=True)
        with open(pairs_path, 'wb') as pairs_file:
            pickle.dump(pairs_dict, pairs_file)


base_path = './data/content/'
base_result_path = './data/statistics/'

count_pairs(get_text_stem_files(base_path))
count_pairs(get_title_stem_files(base_path))
# Out:
# 38113

# %%
def count_hop_pairs(file_generator):
    cnt = 0
    for file_path in file_generator:
        print('\r{}'.format(cnt), end='')
        cnt += 1
        hop_pairs_dict = defaultdict(int)
        with open(file_path, 'r', encoding='UTF-8', errors='ignore') as file:
            text = file.read().strip()
            words = text.split(' ')
            for idx in range(len(words) - 2):
                hop_pairs_dict[(words[idx], words[idx + 2])] += 1

        hop_pairs_path = file_path_to_hop_pairs_path(file_path)
        os.makedirs(os.path.dirname(hop_pairs_path), exist_ok=True)
        with open(hop_pairs_path, 'wb') as pairs_file:
            pickle.dump(hop_pairs_dict, pairs_file)


base_path = './data/content/'
base_result_path = './data/statistics/'

count_hop_pairs(get_text_stem_files(base_path))
count_hop_pairs(get_title_stem_files(base_path))
# Out:
# 38113

# %%
def count_hop_hop_pairs(file_generator):
    cnt = 0
    for file_path in file_generator:
        print('\r{}'.format(cnt), end='')
        cnt += 1
        hop_hop_pairs_dict = defaultdict(int)
        with open(file_path, 'r', encoding='UTF-8', errors='ignore') as file:
            text = file.read().strip()
            words = text.split(' ')
            for idx in range(len(words) - 3):
                hop_hop_pairs_dict[(words[idx], words[idx + 3])] += 1

        hop_hop_pairs_path = file_path_to_hop_hop_pairs_path(file_path)
        os.makedirs(os.path.dirname(hop_hop_pairs_path), exist_ok=True)
        with open(hop_hop_pairs_path, 'wb') as pairs_file:
            pickle.dump(hop_hop_pairs_dict, pairs_file)


base_path = './data/content/'
base_result_path = './data/statistics/'

count_hop_hop_pairs(get_text_stem_files(base_path))
count_hop_hop_pairs(get_title_stem_files(base_path))
# Out:
# 38113

# %%
# attempt to implement an assessor evaluation
# (the result hasn't been improved)

sample_path = './data/sample.technosphere.ir1.textrelevance.submission.txt'
base_path = './data/path.numerate.sort.txt'
base_result_path = './data/statistics/b25.similarity.pkz'
N = 400

def query_to_doc_order(base):
    current_id = 1
    min = 1
    max = 1
    query_docs = defaultdict(list)
    docs_query = defaultdict(list)

    for i in range(1, N):
        query_docs[i] = [[], []]

    with open(base, 'r', encoding='UTF-8') as file:
        file.readline()
        for line in file:
            query_id, doc_id = map(int, (part.strip() for part in line.split(',')))
            docs_query[doc_id].append(query_id)
            if query_id == current_id:
                if min <= doc_id <= max:
                    max += 1
                else:
                    query_docs[query_id][1].append(doc_id)
            else:
                query_docs[current_id][0] = [min, max - 1]
                current_id = query_id
                min = max
                if min <= doc_id <= max:
                    max += 1
                else:
                    query_docs[query_id][1].append(doc_id)
        query_docs[query_id][0] = [min, max - 1]
    return query_docs, docs_query

def path_to_text(base, docs):
    texts = list()
    with open(base, 'r', encoding='UTF-8') as file:
        for line in file:
            path, doc_id = (part.strip() for part in line.split('\t'))
            doc_id = int(doc_id)
            if doc_id in docs:
                tokens = path.split('/')
                text_path = path.replace(tokens[3], tokens[3] + '_text_stem')
                title_path = path.replace(tokens[3], tokens[3] + '_title_stem')
                with open(text_path, 'r', encoding='UTF-8') as text, \
                    open(title_path, 'r', encoding='UTF-8') as title:
                    t1 = title.read().strip()
                    t2 = text.read().strip()
                    texts.append((t1 + ' ' + t2).split())
    return texts

def py_bm25_sim(base, dest, sample):
    cnt = 0
    query_docs, docs_query = query_to_doc_order(sample)
    query_docs_sim = defaultdict(list)

    for i in range(1, N):
        cnt += 1
        print('\r{}'.format(cnt), end='')
        texts = path_to_text(base, list(range(query_docs[i][0][0], query_docs[i][0][1])) + query_docs[i][1])
        result = get_bm25_weights(texts, 4)
        query_docs_sim[i] = result

    with open(dest, 'wb', encoding='UTF-8') as docs_sim_file:
        pickle.dump(query_docs_sim, docs_sim_file)

# %%
def get_idf(word):
    cf = text_cf_dict[word] + title_cf_dict[word] + 1
    df = text_df_dict[word] + title_df_dict[word] + 1
    idf_1 = -math.log(1 - math.exp(-1.5 * cf / N_DOCUMENTS)) - math.log(df / N_DOCUMENTS)
    idf_2 = math.log(TOTAL_LEMMS / cf)
    return (idf_1 + idf_2) / 2


def get_score(query, doc_id, doc_base_path):
    if len(query) == 0:
        return 0

    text_tf_path = doc_base_path \
        .replace('content', 'statistics/tf').replace('/doc.', '_text_stem/doc.').replace('.dat', '.pkz')
    title_tf_path = doc_base_path \
        .replace('content', 'statistics/tf').replace('/doc.', '_title_stem/doc.').replace('.dat', '.pkz')

    text_pairs_path = doc_base_path \
        .replace('content', 'statistics/pairs').replace('/doc.', '_text_stem/doc.').replace('.dat', '.pkz')
    title_pairs_path = doc_base_path \
        .replace('content', 'statistics/pairs').replace('/doc.', '_title_stem/doc.').replace('.dat', '.pkz')

    text_hop_pairs_path = doc_base_path \
        .replace('content', 'statistics/hop_pairs').replace('/doc.', '_text_stem/doc.').replace('.dat', '.pkz')
    title_hop_pairs_path = doc_base_path \
        .replace('content', 'statistics/hop_pairs').replace('/doc.', '_title_stem/doc.').replace('.dat', '.pkz')

    text_hop_hop_pairs_path = doc_base_path \
        .replace('content', 'statistics/hop_hop_pairs').replace('/doc.', '_text_stem/doc.').replace('.dat', '.pkz')
    title_hop_hop_pairs_path = doc_base_path \
        .replace('content', 'statistics/hop_hop_pairs').replace('/doc.', '_title_stem/doc.').replace('.dat', '.pkz')

    score = 0
    with open(text_tf_path, 'rb') as text_tf_file, \
            open(title_tf_path, 'rb') as title_tf_file, \
            open(text_pairs_path, 'rb') as text_pairs_file, \
            open(title_pairs_path, 'rb') as title_pairs_file, \
            open(text_hop_pairs_path, 'rb') as text_hop_pairs_file, \
            open(title_hop_pairs_path, 'rb') as title_hop_pairs_file, \
            open(text_hop_hop_pairs_path, 'rb') as text_hop_hop_pairs_file, \
            open(title_hop_hop_pairs_path, 'rb') as title_hop_hop_pairs_file:

        text_tf_dict = pickle.load(text_tf_file)
        title_tf_dict = pickle.load(title_tf_file)

        text_pairs_dict = pickle.load(text_pairs_file)
        title_pairs_dict = pickle.load(title_pairs_file)

        text_hop_pairs_dict = pickle.load(text_hop_pairs_file)
        title_hop_pairs_dict = pickle.load(title_hop_pairs_file)

        text_hop_hop_pairs_dict = pickle.load(text_hop_hop_pairs_file)
        title_hop_hop_pairs_dict = pickle.load(title_hop_hop_pairs_file)

        words = query.split(' ')
        W_single = 0
        W_pair = 0
        W_all = 0

        doclen = float(text_doclen_dict[doc_id] + title_doclen_dict[doc_id])
        N_missed = 0
        sum_log_p = 0

        for word in words:
            tf = text_tf_dict[word] + title_tf_dict[word]
            hdr = title_tf_dict[word]

            IDF = get_idf(word)

            TF_1 = tf / (tf + K1 + K2 * doclen)
            TF_2 = 1 if hdr > 0 else 0

            W_single += IDF * (TF_1 + 1.5 * TF_2)

            sum_log_p += IDF
            if tf < 1:
                N_missed += 1

        for word_1, word_2 in combinations(words, 2):
            IDF_1 = get_idf(word_1)
            IDF_2 = get_idf(word_2)

            pair_1_2 = text_pairs_dict[(word_1, word_2)] + title_pairs_dict[(word_1, word_2)]
            pair_2_1 = text_pairs_dict[(word_2, word_1)] + title_pairs_dict[(word_2, word_1)]
            hop_pair_1_2 = text_hop_pairs_dict[(word_1, word_2)] + title_hop_pairs_dict[(word_1, word_2)]
            hop_hop_pair_1_2 = text_hop_hop_pairs_dict[(word_1, word_2)] + title_hop_hop_pairs_dict[(word_1, word_2)]

            TF = (W_P * pair_1_2 + W_S * hop_pair_1_2 + W_W * hop_hop_pair_1_2 + W_I * pair_2_1)
            W_pair += (IDF_1 + IDF_2) * TF / (1 + TF)

        W_all = sum_log_p * (0.03 ** N_missed)

        score = W_single + W_PAIR * W_pair + W_ALL * W_all

    return score


n_p_path = './data/numerate.path.pkz'

target_docs_path = './data/sample.technosphere.ir1.textrelevance.submission.txt'

text_doclen_path = './data/statistics/text_doclen.pkz'
title_doclen_path = './data/statistics/title_doclen.pkz'
text_cf_path = './data/statistics/text_cf_count.pkz'
title_cf_path = './data/statistics/title_cf_count.pkz'
text_df_path = './data/statistics/text_df_count.pkz'
title_df_path = './data/statistics/title_df_count.pkz'

with open(text_cf_path, 'rb') as text_cf_file, \
        open(title_cf_path, 'rb') as title_cf_file, \
        open(text_df_path, 'rb') as text_df_file, \
        open(title_df_path, 'rb') as title_df_file, \
        open(text_doclen_path, 'rb') as text_doclen_file, \
        open(title_doclen_path, 'rb') as title_doclen_file:

    text_cf_dict = pickle.load(text_cf_file)
    title_cf_dict = pickle.load(title_cf_file)
    text_df_dict = pickle.load(text_df_file)
    title_df_dict = pickle.load(title_df_file)
    text_doclen_dict = pickle.load(text_doclen_file)
    title_doclen_dict = pickle.load(title_doclen_file)


def process(part_idx):
    queries_path = './data/queries.numerate_processed_chunks/chunk_{0}.txt'.format(part_idx)
    submition_path = './data/queries.numerate_processed_chunks/results/chunk_{0}.txt'.format(part_idx)

    queries = defaultdict(tuple)
    with open(queries_path, 'r', encoding='UTF-8', errors='ignore') as file:
        for line in file:
            idx, query_main, query_ex, query_trans_main, query_trans_ex = (part.strip() for part in line.split('\t'))
            queries[int(idx)] = (query_main, query_ex, query_trans_main, query_trans_ex)

    with open(n_p_path, 'rb') as file:
        n_p_dict = pickle.load(file)

    result = defaultdict(list)
    queries_processed = 0
    checked = False
    with open(target_docs_path, 'r', encoding='UTF-8', errors='ignore') as file:
        file.readline()
        for line in file:
            query_id, doc_id = (int(val) for val in line.strip().split(','))
            if query_id not in queries:
                continue
            try:
                query_main, query_ex, query_trans_main, query_trans_ex = queries[query_id]
                score_main = get_score(query_main, doc_id, n_p_dict[doc_id])
                score_ex = get_score(query_ex, doc_id, n_p_dict[doc_id])
                score_trans_main = get_score(query_trans_main, doc_id, n_p_dict[doc_id])
                score_trans_ex = get_score(query_trans_ex, doc_id, n_p_dict[doc_id])
                score = max(score_main, score_ex, score_trans_main, score_trans_ex)
                if not checked:
                    print(part_idx,
                          doc_id,
                          np.round(score_main, 3),
                          np.round(score_ex, 3),
                          np.round(score_trans_main, 3),
                          np.round(score_trans_ex, 3))
                    checked = True
            except KeyError:
                score = 0
            result[query_id].append((doc_id, score))
            queries_processed += 1

    for key in result.keys():
        result[key] = sorted(result[key], key=lambda val: val[1], reverse=True)

    with open(submition_path, 'w') as file:
        file.write('QueryId,DocumentId\n')
        for key in sorted(result.keys()):
            for doc_id, _ in result[key]:
                file.write(str(key) + ',' + str(doc_id) + '\n')
    print(part_idx, 'done')


pool = multiprocessing.pool.ThreadPool(4)
pool.map(process, list(range(1, 5)))
pool.close()
pool.join()
# Out:
# 1 1 16.599 0 16.93 0
# 4 28658 7.591 0 5.829 0
# 2 3 192159505 37.045 0 77.388 0
#  13.244 0 10.629 0
# 1 done
# 4 done
# 2 done
# 3 done

# %%
base_path = './data/queries.numerate_processed_chunks/results/'
submition_path = base_path + 'out.submition_{0}.txt'.format(str(time.time()))

paths = sorted([f for f in os.listdir(base_path) if f.find('chunk') >= 0])

with open(submition_path, 'w') as submition_file:
    submition_file.write('QueryId,DocumentId\n')
    for path in paths:
        with open(base_path + path, 'r') as file:
            file.readline()
            for line in file:
                submition_file.write(line)
